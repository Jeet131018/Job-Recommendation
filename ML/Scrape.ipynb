# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

from bs4 import BeautifulSoup
from time import sleep
from skill_list import skills
import os

import pandas as pd

# %%
driver_path = "./chromedriver.exe"
service = Service(executable_path=driver_path)
options = webdriver.ChromeOptions()
web = webdriver.Chrome(service=service,options=options)
final_data=[]
final_data2=[]

# %%
def do():
    ex = []
    wrong = []
    
    # db = client['jobs'] 
    # db.create_collection('narkuri') 
    # print("Database created........") 
    t = 0
    # url = "https://www.naukri.com/Cryptography-jobs?k=Cryptography"
    # print(url)
    # web.get(url)
    
    # html = web.page_source
    for search in skills:
        try:
            print("index:" ,t)
            t+=1
            search_title = search
            url = "https://www.naukri.com/" + search_title + "-jobs?k=" + search_title
            print(url)
            web.get(url)

            sleep(1)
            html = web.page_source
            soup = BeautifulSoup(html)

            data = []

            TITLE         = soup.find_all("a", {"class": "title"})
            EXPERIENCE    = soup.find_all("li", {"class": "experience"}) 
            SALARY        = soup.find_all("li", {"class": "salary"})
            LOCATION      = soup.find_all("li", {"class": "location"})
            SKILLS        = soup.find_all("ul", {"class": "has-description"})   

            for i in range(20):
                
                x = {
                    'title'     : TITLE[i].text,
                    'url'       : TITLE[i].get('href'),
                    'experience': EXPERIENCE[i].text,
                    'salary'    : SALARY[i].text,
                    'location'  : (LOCATION[i].text).split(', '),
                    'skills'    : [j.text for j in SKILLS[i]],
                    'search_type'      : search_title
                }

                data.append(x)
                final_data2.append(x)
            
            
            final_data.append(data)
            # print(data)
            # db = client['jobs'] 
            # mydb = db['narkuri']

            # x = mydb.insert_many(data)

        except Exception as e:
            ex.append(e)
            wrong.append((search , url))
    
    # print(final_data)

    

do()
# Out:
# index: 0
# https://www.naukri.com/HTML-jobs?k=HTML
# index: 1
# https://www.naukri.com/Cryptography-jobs?k=Cryptography
# index: 2
# https://www.naukri.com/Data structures-jobs?k=Data structures
# index: 3
# https://www.naukri.com/Blockchain-jobs?k=Blockchain
# index: 4
# https://www.naukri.com/Cryptography-jobs?k=Cryptography
# index: 5
# https://www.naukri.com/Smart contracts-jobs?k=Smart contracts
# index: 6
# https://www.naukri.com/Outlook-jobs?k=Outlook
# index: 7
# https://www.naukri.com/Netbeans-jobs?k=Netbeans
# index: 8
# https://www.naukri.com/python-jobs?k=python
# index: 9
# https://www.naukri.com/JAVA-jobs?k=JAVA
# index: 10
# https://www.naukri.com/Networking-jobs?k=Networking
# index: 11
# https://www.naukri.com/DML-jobs?k=DML
# index: 12
# https://www.naukri.com/Rest Web Services-jobs?k=Rest Web Services
# index: 13
# https://www.naukri.com/Windows-jobs?k=Windows
# index: 14
# https://www.naukri.com/MS Power Point.-jobs?k=MS Power Point.
# index: 15
# https://www.naukri.com/MS-Access-jobs?k=MS-Access
# index: 16
# https://www.naukri.com/technical assistance.-jobs?k=technical assistance.
# index: 17
# https://www.naukri.com/SAP-jobs?k=SAP
# index: 18
# https://www.naukri.com/UNIX-jobs?k=UNIX
# index: 19
# https://www.naukri.com/Citrix Xen Server-jobs?k=Citrix Xen Server
# index: 20
# https://www.naukri.com/Web Application testing-jobs?k=Web Application testing
# index: 21
# https://www.naukri.com/Cyara-jobs?k=Cyara
# index: 22
# https://www.naukri.com/Linux-jobs?k=Linux
# index: 23
# https://www.naukri.com/MICROSOFT-jobs?k=MICROSOFT
# index: 24
# https://www.naukri.com/Nagios-jobs?k=Nagios
# index: 25
# https://www.naukri.com/Software Testing-jobs?k=Software Testing
# index: 26
# https://www.naukri.com/GIT-jobs?k=GIT
# index: 27
# https://www.naukri.com/Eclipse-jobs?k=Eclipse
# index: 28
# https://www.naukri.com/Sonar QubeC#.net-jobs?k=Sonar QubeC#.net
# index: 29
# https://www.naukri.com/Apache-jobs?k=Apache
# index: 30
# https://www.naukri.com/Data Modeling-jobs?k=Data Modeling
# index: 31
# https://www.naukri.com/Database-jobs?k=Database
# index: 32
# https://www.naukri.com/MySQL-jobs?k=MySQL
# index: 33
# https://www.naukri.com/Angular Js-jobs?k=Angular Js
# index: 34
# https://www.naukri.com/Networking-jobs?k=Networking
# index: 35
# https://www.naukri.com/AWS-jobs?k=AWS
# index: 36
# https://www.naukri.com/java servlet-jobs?k=java servlet
# index: 37
# https://www.naukri.com/Jquery-jobs?k=Jquery
# index: 38
# https://www.naukri.com/Selenium-jobs?k=Selenium
# index: 39
# https://www.naukri.com/Selenium Webdriver-jobs?k=Selenium Webdriver
# index: 40
# https://www.naukri.com/NoSQL-jobs?k=NoSQL
# index: 41
# https://www.naukri.com/GWT-jobs?k=GWT
# index: 42
# https://www.naukri.com/CSS-jobs?k=CSS
# index: 43
# https://www.naukri.com/Computer-jobs?k=Computer
# index: 44
# https://www.naukri.com/SQL Server 2010-jobs?k=SQL Server 2010
# index: 45
# https://www.naukri.com/Web Development-jobs?k=Web Development
# index: 46
# https://www.naukri.com/Internet Of Things-jobs?k=Internet Of Things
# index: 47
# https://www.naukri.com/Windows/XP-jobs?k=Windows/XP
# index: 48
# https://www.naukri.com/R Studio-jobs?k=R Studio
# index: 49
# https://www.naukri.com/network engineers-jobs?k=network engineers
# index: 50
# https://www.naukri.com/Java.-jobs?k=Java.
# index: 51
# https://www.naukri.com/MS OFFICE-jobs?k=MS OFFICE
# index: 52
# https://www.naukri.com/Testing-jobs?k=Testing
# index: 53
# https://www.naukri.com/CCNA-jobs?k=CCNA
# index: 54
# https://www.naukri.com/ipsec-jobs?k=ipsec
# index: 55
# https://www.naukri.com/ANDROID-jobs?k=ANDROID
# index: 56
# https://www.naukri.com/HSRP-jobs?k=HSRP
# index: 57
# https://www.naukri.com/CPP-jobs?k=CPP
# index: 58
# https://www.naukri.com/Application Designer-jobs?k=Application Designer
# index: 59
# https://www.naukri.com/PowerShell-jobs?k=PowerShell
# index: 60
# https://www.naukri.com/MS Word-jobs?k=MS Word
# index: 61
# https://www.naukri.com/Ms-Access-jobs?k=Ms-Access
# index: 62
# https://www.naukri.com/NetBeans-jobs?k=NetBeans
# index: 63
# https://www.naukri.com/Cloud Computing-jobs?k=Cloud Computing
# index: 64
# https://www.naukri.com/OpenShit-jobs?k=OpenShit
# index: 65
# https://www.naukri.com/Web Designing-jobs?k=Web Designing
# index: 66
# https://www.naukri.com/Jdeveloper-jobs?k=Jdeveloper
# index: 67
# https://www.naukri.com/computer and firesafety-jobs?k=computer and firesafety
# index: 68
# https://www.naukri.com/HTML-jobs?k=HTML
# index: 69
# https://www.naukri.com/Windows and Linux-jobs?k=Windows and Linux
# index: 70
# https://www.naukri.com/CISCO-jobs?k=CISCO
# index: 71
# https://www.naukri.com/Azure-jobs?k=Azure
# index: 72
# https://www.naukri.com/SAS-jobs?k=SAS
# index: 73
# https://www.naukri.com/Sql-jobs?k=Sql
# index: 74
# https://www.naukri.com/SQL developer-jobs?k=SQL developer
# index: 75
# https://www.naukri.com/Computer Networks-jobs?k=Computer Networks
# index: 76
# https://www.naukri.com/php-jobs?k=php
# index: 77
# https://www.naukri.com/Ansible-jobs?k=Ansible
# index: 78
# https://www.naukri.com/Excel-jobs?k=Excel
# index: 79
# https://www.naukri.com/Apache Tomcat-jobs?k=Apache Tomcat
# index: 80
# https://www.naukri.com/Ansible-jobs?k=Ansible
# index: 81
# https://www.naukri.com/Bootstrap-jobs?k=Bootstrap
# index: 82
# https://www.naukri.com/JavaScript-jobs?k=JavaScript
# index: 83
# https://www.naukri.com/SQL-jobs?k=SQL
# index: 84
# https://www.naukri.com/VB.net-jobs?k=VB.net
# index: 85
# https://www.naukri.com/APPLICATION SOFTWARE-jobs?k=APPLICATION SOFTWARE
# index: 86
# https://www.naukri.com/Micro Services-jobs?k=Micro Services
# index: 87
# https://www.naukri.com/Java Script-jobs?k=Java Script
# index: 88
# https://www.naukri.com/Eclipse IDE.-jobs?k=Eclipse IDE.
# index: 89
# https://www.naukri.com/Bash-jobs?k=Bash
# index: 90
# https://www.naukri.com/Putty-jobs?k=Putty
# index: 91
# https://www.naukri.com/SPUFI-jobs?k=SPUFI
# index: 92
# https://www.naukri.com/Agile-jobs?k=Agile
# index: 93
# https://www.naukri.com/Hacking-jobs?k=Hacking
# index: 94
# https://www.naukri.com/bgp-jobs?k=bgp
# index: 95
# https://www.naukri.com/Invoice-jobs?k=Invoice
# index: 96
# https://www.naukri.com/AMDP.-jobs?k=AMDP.
# index: 97
# https://www.naukri.com/ASP-jobs?k=ASP
# index: 98
# https://www.naukri.com/Artificial Intelligence-jobs?k=Artificial Intelligence
# index: 99
# https://www.naukri.com/Application / Software Development-jobs?k=Application / Software Development
# index: 100
# https://www.naukri.com/mpls-jobs?k=mpls
# index: 101
# https://www.naukri.com/Program Management-jobs?k=Program Management
# index: 102
# https://www.naukri.com/C-jobs?k=C
# index: 103
# https://www.naukri.com/MS-Access-jobs?k=MS-Access
# index: 104
# https://www.naukri.com/Java-jobs?k=Java
# index: 105
# https://www.naukri.com/Kibana-jobs?k=Kibana
# index: 106
# https://www.naukri.com/Maven-jobs?k=Maven
# index: 107
# https://www.naukri.com/Open VZ-jobs?k=Open VZ
# index: 108
# https://www.naukri.com/ASP.NET-jobs?k=ASP.NET
# index: 109
# https://www.naukri.com/C# .NET-jobs?k=C# .NET
# index: 110
# https://www.naukri.com/AWS-jobs?k=AWS
# index: 111
# https://www.naukri.com/java script-jobs?k=java script
# index: 112
# https://www.naukri.com/Hibernate-jobs?k=Hibernate
# index: 113
# https://www.naukri.com/routing protocols.-jobs?k=routing protocols.
# index: 114
# https://www.naukri.com/cricket-jobs?k=cricket
# index: 115
# https://www.naukri.com/Automation-jobs?k=Automation
# index: 116
# https://www.naukri.com/MySQL-jobs?k=MySQL
# index: 117
# https://www.naukri.com/Lithium-jobs?k=Lithium
# index: 118
# https://www.naukri.com/Git-jobs?k=Git
# index: 119
# https://www.naukri.com/GCP-jobs?k=GCP
# index: 120
# https://www.naukri.com/JSON-jobs?k=JSON
# index: 121
# https://www.naukri.com/Maria-DB-jobs?k=Maria-DB
# index: 122
# https://www.naukri.com/Spring-jobs?k=Spring
# index: 123
# https://www.naukri.com/Socket Programming-jobs?k=Socket Programming
# index: 124
# https://www.naukri.com/EJB-jobs?k=EJB
# index: 125
# https://www.naukri.com/Nexus-jobs?k=Nexus
# index: 126
# https://www.naukri.com/Html5-jobs?k=Html5
# index: 127
# https://www.naukri.com/PostgreSQL-jobs?k=PostgreSQL
# index: 128
# https://www.naukri.com/Ms Word and Power Point-jobs?k=Ms Word and Power Point
# index: 129
# https://www.naukri.com/ASP.NET-jobs?k=ASP.NET
# index: 130
# https://www.naukri.com/CSS 3.0-jobs?k=CSS 3.0
# index: 131
# https://www.naukri.com/Hyper--jobs?k=Hyper-
# index: 132
# https://www.naukri.com/Servlet-jobs?k=Servlet
# index: 133
# https://www.naukri.com/PowerPoint-jobs?k=PowerPoint
# index: 134
# https://www.naukri.com/JMS-jobs?k=JMS
# index: 135
# https://www.naukri.com/multicast-jobs?k=multicast
# index: 136
# https://www.naukri.com/Windows Services-jobs?k=Windows Services
# index: 137
# https://www.naukri.com/IoT-jobs?k=IoT
# index: 138
# https://www.naukri.com/Hardware & Networking-jobs?k=Hardware & Networking
# index: 139
# https://www.naukri.com/SAPUI5-jobs?k=SAPUI5
# index: 140
# https://www.naukri.com/Machine Learning-jobs?k=Machine Learning
# index: 141
# https://www.naukri.com/TRAINING-jobs?k=TRAINING
# index: 142
# https://www.naukri.com/SQL-jobs?k=SQL
# index: 143
# https://www.naukri.com/C++-jobs?k=C++
# index: 144
# https://www.naukri.com/Gephi-jobs?k=Gephi
# index: 145
# https://www.naukri.com/Go Lang-jobs?k=Go Lang
# index: 146
# https://www.naukri.com/AngularJs-jobs?k=AngularJs
# index: 147
# https://www.naukri.com/Object Oriented Programming-jobs?k=Object Oriented Programming
# index: 148
# https://www.naukri.com/Struts-jobs?k=Struts
# index: 149
# https://www.naukri.com/Application & Web Servers: Sciencelogic (EM7)-jobs?k=Application & Web Servers: Sciencelogic (EM7)
# index: 150
# https://www.naukri.com/Java/C/C++ -jobs?k=Java/C/C++
# index: 151
# https://www.naukri.com/M.S. OFFICE-jobs?k=M.S. OFFICE
# index: 152
# https://www.naukri.com/Billing-jobs?k=Billing
# index: 153
# https://www.naukri.com/active directory-jobs?k=active directory
# index: 154
# https://www.naukri.com/Big dataASP Technical specifications creation-jobs?k=Big dataASP Technical specifications creation
# index: 155
# https://www.naukri.com/Confidential Record Keeping-jobs?k=Confidential Record Keeping
# index: 156
# https://www.naukri.com/Postman-jobs?k=Postman
# index: 157
# https://www.naukri.com/Goal Oriented & Self Motivated-jobs?k=Goal Oriented & Self Motivated
# index: 158
# https://www.naukri.com/VB-jobs?k=VB
# index: 159
# https://www.naukri.com/Content-jobs?k=Content
# index: 160
# https://www.naukri.com/ SAPUI5 (Primary Skill)-jobs?k= SAPUI5 (Primary Skill)
# index: 161
# https://www.naukri.com/Mongo DB-jobs?k=Mongo DB
# index: 162
# https://www.naukri.com/Market Basket Analysis-jobs?k=Market Basket Analysis
# index: 163
# https://www.naukri.com/Familiar with SQL-jobs?k=Familiar with SQL
# index: 164
# https://www.naukri.com/Hospitality-jobs?k=Hospitality
# index: 165
# https://www.naukri.com/Web Authoring Tools HTML 5-jobs?k=Web Authoring Tools HTML 5
# index: 166
# https://www.naukri.com/Reporting Tools: Vportal-jobs?k=Reporting Tools: Vportal
# index: 167
# https://www.naukri.com/Network Management-jobs?k=Network Management
# index: 168
# https://www.naukri.com/Operations-jobs?k=Operations
# index: 169
# https://www.naukri.com/Inversion of Control-jobs?k=Inversion of Control
# index: 170
# https://www.naukri.com/MS office-jobs?k=MS office
# index: 171
# https://www.naukri.com/Monthly patching update activity and server owner approval / RFC follow-ups.-jobs?k=Monthly patching update activity and server owner approval / RFC follow-ups.
# index: 172
# https://www.naukri.com/Ajax &JQuery-jobs?k=Ajax &JQuery
# index: 173
# https://www.naukri.com/rogramming  :C/C++-jobs?k=rogramming  :C/C++
# index: 174
# https://www.naukri.com/problem solving-jobs?k=problem solving
# index: 175
# https://www.naukri.com/Functional Testing-jobs?k=Functional Testing
# index: 176
# https://www.naukri.com/Octopus-jobs?k=Octopus
# index: 177
# https://www.naukri.com/good at communication-jobs?k=good at communication
# index: 178
# https://www.naukri.com/angular-jobs?k=angular
# index: 179
# https://www.naukri.com/PL/SQL Developer-jobs?k=PL/SQL Developer
# index: 180
# https://www.naukri.com/Windows XP-jobs?k=Windows XP
# index: 181
# https://www.naukri.com/ospf-jobs?k=ospf
# index: 182
# https://www.naukri.com/Powershell-jobs?k=Powershell
# index: 183
# https://www.naukri.com/work devotee-jobs?k=work devotee
# index: 184
# https://www.naukri.com/APACHE-jobs?k=APACHE
# index: 185
# https://www.naukri.com/Android Studio-jobs?k=Android Studio
# index: 186
# https://www.naukri.com/exchange-jobs?k=exchange
# index: 187
# https://www.naukri.com/Frontend HTML and .Net-jobs?k=Frontend HTML and .Net
# index: 188
# https://www.naukri.com/DBMS-jobs?k=DBMS
# index: 189
# https://www.naukri.com/excellent in various sports like soccer-jobs?k=excellent in various sports like soccer
# index: 190
# https://www.naukri.com/Predictive Modelling-jobs?k=Predictive Modelling
# index: 191
# https://www.naukri.com/KVM-jobs?k=KVM
# index: 192
# https://www.naukri.com/JQuery.-jobs?k=JQuery.
# index: 193
# https://www.naukri.com/ACCESS-jobs?k=ACCESS
# index: 194
# https://www.naukri.com/Work on Windows 7-jobs?k=Work on Windows 7
# index: 195
# https://www.naukri.com/CRM-jobs?k=CRM
# index: 196
# https://www.naukri.com/Selenium (Selenium IDE-jobs?k=Selenium (Selenium IDE
# index: 197
# https://www.naukri.com/RESOURCE PLANNING-jobs?k=RESOURCE PLANNING
# index: 198
# https://www.naukri.com/PowerPoint Language: Fluent in verbal-jobs?k=PowerPoint Language: Fluent in verbal
# index: 199
# https://www.naukri.com/STL)-jobs?k=STL)
# index: 200
# https://www.naukri.com/good time management skills-jobs?k=good time management skills
# index: 201
# https://www.naukri.com/DNS-jobs?k=DNS
# index: 202
# https://www.naukri.com/than 1 year)-jobs?k=than 1 year)
# index: 203
# https://www.naukri.com/Accounts Payable-FI-A/P-jobs?k=Accounts Payable-FI-A/P
# index: 204
# https://www.naukri.com/java-jobs?k=java
# index: 205
# https://www.naukri.com/Mac-jobs?k=Mac
# index: 206
# https://www.naukri.com/IDE: Eclipse-jobs?k=IDE: Eclipse
# index: 207
# https://www.naukri.com/JQuery-jobs?k=JQuery
# index: 208
# https://www.naukri.com/PHP-jobs?k=PHP
# index: 209
# https://www.naukri.com/kannada-jobs?k=kannada
# index: 210
# https://www.naukri.com/IT Literacy-jobs?k=IT Literacy
# index: 211
# https://www.naukri.com/SIEM-jobs?k=SIEM
# index: 212
# https://www.naukri.com/Highly Dedicated towards work-jobs?k=Highly Dedicated towards work
# index: 213
# https://www.naukri.com/RDBMS: MySQL-jobs?k=RDBMS: MySQL
# index: 214
# https://www.naukri.com/MS OFFICE (MS excel-jobs?k=MS OFFICE (MS excel
# index: 215
# https://www.naukri.com/Ansys-jobs?k=Ansys
# index: 216
# https://www.naukri.com/Bid management-jobs?k=Bid management
# index: 217
# https://www.naukri.com/Corporate Communications-jobs?k=Corporate Communications
# index: 218
# https://www.naukri.com/Wireshark-jobs?k=Wireshark
# index: 219
# https://www.naukri.com/OpenStack-jobs?k=OpenStack
# index: 220
# https://www.naukri.com/Front end/GUI Tools programming: Adobe Flex-jobs?k=Front end/GUI Tools programming: Adobe Flex
# index: 221
# https://www.naukri.com/team player-jobs?k=team player
# index: 222
# https://www.naukri.com/XML-jobs?k=XML
# index: 223
# https://www.naukri.com/Good communication - written and oral skills-jobs?k=Good communication - written and oral skills
# index: 224
# https://www.naukri.com/Tally-jobs?k=Tally
# index: 225
# https://www.naukri.com/TestNG-jobs?k=TestNG
# index: 226
# https://www.naukri.com/Team-Player-jobs?k=Team-Player
# index: 227
# https://www.naukri.com/Database MySQL-jobs?k=Database MySQL
# index: 228
# https://www.naukri.com/Tolerant and Flexible to Different Situations-jobs?k=Tolerant and Flexible to Different Situations
# index: 229
# https://www.naukri.com/Data Driven-jobs?k=Data Driven
# index: 230
# https://www.naukri.com/Building good relationship with people.-jobs?k=Building good relationship with people.
# index: 231
# https://www.naukri.com/Marathi-jobs?k=Marathi
# index: 232
# https://www.naukri.com/Source Control Management: SVN-jobs?k=Source Control Management: SVN
# index: 233
# https://www.naukri.com/ADDITIONAL INFORMATION-jobs?k=ADDITIONAL INFORMATION
# index: 234
# https://www.naukri.com/wsus-jobs?k=wsus
# index: 235
# https://www.naukri.com/C#-jobs?k=C#
# index: 236
# https://www.naukri.com/MATLAB-jobs?k=MATLAB
# index: 237
# https://www.naukri.com/Oracle System upgrades-jobs?k=Oracle System upgrades
# index: 238
# https://www.naukri.com/Mobile Applications-jobs?k=Mobile Applications
# index: 239
# https://www.naukri.com/Page Object model-jobs?k=Page Object model
# index: 240
# https://www.naukri.com/Microsoft Azure-jobs?k=Microsoft Azure
# index: 241
# https://www.naukri.com/Selenium-jobs?k=Selenium
# index: 242
# https://www.naukri.com/Design Patterns-jobs?k=Design Patterns
# index: 243
# https://www.naukri.com/Typewriting-jobs?k=Typewriting
# index: 244
# https://www.naukri.com/Sql server 2005-jobs?k=Sql server 2005
# index: 245
# https://www.naukri.com/Docker-jobs?k=Docker
# index: 246
# https://www.naukri.com/MYSQL-jobs?k=MYSQL
# index: 247
# https://www.naukri.com/Network Security-jobs?k=Network Security
# index: 248
# https://www.naukri.com/Database-jobs?k=Database
# index: 249
# https://www.naukri.com/Project management-jobs?k=Project management
# index: 250
# https://www.naukri.com/D3js-jobs?k=D3js
# index: 251
# https://www.naukri.com/Technical Experience: - Automation Testing (REST API-jobs?k=Technical Experience: - Automation Testing (REST API
# index: 252
# https://www.naukri.com/SQL Server-jobs?k=SQL Server
# index: 253
# https://www.naukri.com/Bamboo-jobs?k=Bamboo
# index: 254
# https://www.naukri.com/SAP UI5/Fiori-jobs?k=SAP UI5/Fiori
# index: 255
# https://www.naukri.com/LINUX-jobs?k=LINUX
# index: 256
# https://www.naukri.com/people and environments.-jobs?k=people and environments.
# index: 257
# https://www.naukri.com/SAP HANA-jobs?k=SAP HANA
# index: 258
# https://www.naukri.com/Scrum Ma-jobs?k=Scrum Ma
# index: 259
# https://www.naukri.com/7-jobs?k=7
# index: 260
# https://www.naukri.com/Service Virtualization)-jobs?k=Service Virtualization)
# index: 261
# https://www.naukri.com/Computer: Proficient in Windows-jobs?k=Computer: Proficient in Windows
# index: 262
# https://www.naukri.com/WAF-jobs?k=WAF
# index: 263
# https://www.naukri.com/Git-jobs?k=Git
# index: 264
# https://www.naukri.com/Banking-jobs?k=Banking
# index: 265
# https://www.naukri.com/Relay server.-jobs?k=Relay server.
# index: 266
# https://www.naukri.com/Sauce Labs-jobs?k=Sauce Labs
# index: 267
# https://www.naukri.com/5.0 (E)-jobs?k=5.0 (E)
# index: 268
# https://www.naukri.com/Java & J2EE-jobs?k=Java & J2EE
# index: 269
# https://www.naukri.com/PL-SQL programming-jobs?k=PL-SQL programming
# index: 270
# https://www.naukri.com/Programming  VB-jobs?k=Programming  VB
# index: 271
# https://www.naukri.com/NetBeans-jobs?k=NetBeans
# index: 272
# https://www.naukri.com/Computer Hardware-jobs?k=Computer Hardware
# index: 273
# https://www.naukri.com/great at taking-jobs?k=great at taking
# index: 274
# https://www.naukri.com/Sql Server-jobs?k=Sql Server
# index: 275
# https://www.naukri.com/Catia V6-jobs?k=Catia V6
# index: 276
# https://www.naukri.com/Editing-jobs?k=Editing
# index: 277
# https://www.naukri.com/SQL.-jobs?k=SQL.
# index: 278
# https://www.naukri.com/good communication and listening skills.-jobs?k=good communication and listening skills.
# index: 279
# https://www.naukri.com/Mobile Testing-jobs?k=Mobile Testing
# index: 280
# https://www.naukri.com/McAfee ESM-jobs?k=McAfee ESM
# index: 281
# https://www.naukri.com/PMP trained six sigma yellow belt-jobs?k=PMP trained six sigma yellow belt
# index: 282
# https://www.naukri.com/ Linux-jobs?k= Linux
# index: 283
# https://www.naukri.com/project manager-jobs?k=project manager
# index: 284
# https://www.naukri.com/putty-jobs?k=putty
# index: 285
# https://www.naukri.com/ Windows-jobs?k= Windows
# index: 286
# https://www.naukri.com/R studio-jobs?k=R studio
# index: 287
# https://www.naukri.com/Capable and Hardworking-jobs?k=Capable and Hardworking
# index: 288
# https://www.naukri.com/Microsoft Visual Studio 2010-jobs?k=Microsoft Visual Studio 2010
# index: 289
# https://www.naukri.com/Ubuntu Linux-jobs?k=Ubuntu Linux
# index: 290
# https://www.naukri.com/Ajax.-jobs?k=Ajax.
# index: 291
# https://www.naukri.com/Html-jobs?k=Html
# index: 292
# https://www.naukri.com/Splunk-jobs?k=Splunk
# index: 293
# https://www.naukri.com/Framework & tools :ADF-jobs?k=Framework & tools :ADF
# index: 294
# https://www.naukri.com/Syslog sender-jobs?k=Syslog sender
# index: 295
# https://www.naukri.com/tcl-jobs?k=tcl
# index: 296
# https://www.naukri.com/Basic Computers knowledge-jobs?k=Basic Computers knowledge
# index: 297
# https://www.naukri.com/ADOBE PHOTOSHOP-jobs?k=ADOBE PHOTOSHOP
# index: 298
# https://www.naukri.com/Css-jobs?k=Css
# index: 299
# https://www.naukri.com/ERP SAP R/3 in 4.7-jobs?k=ERP SAP R/3 in 4.7
# index: 300
# https://www.naukri.com/Python-jobs?k=Python
# index: 301
# https://www.naukri.com/Database Management System-jobs?k=Database Management System
# index: 302
# https://www.naukri.com/HttpClient-jobs?k=HttpClient
# index: 303
# https://www.naukri.com/Efficient Individual and Team Player-jobs?k=Efficient Individual and Team Player
# index: 304
# https://www.naukri.com/Oracle 10g-jobs?k=Oracle 10g
# index: 305
# https://www.naukri.com/css-jobs?k=css
# index: 306
# https://www.naukri.com/Tools: RADTool-jobs?k=Tools: RADTool
# index: 307
# https://www.naukri.com/Creo parametric 2.0-jobs?k=Creo parametric 2.0
# index: 308
# https://www.naukri.com/Jenkins-jobs?k=Jenkins
# index: 309
# https://www.naukri.com/Cisco Monitoring Tools: EM7-jobs?k=Cisco Monitoring Tools: EM7
# index: 310
# https://www.naukri.com/Android-jobs?k=Android
# index: 311
# https://www.naukri.com/NETWORKING-jobs?k=NETWORKING
# index: 312
# https://www.naukri.com/10-jobs?k=10
# index: 313
# https://www.naukri.com/Sublime-jobs?k=Sublime
# index: 314
# https://www.naukri.com/Mockito-jobs?k=Mockito
# index: 315
# https://www.naukri.com/Creative Team Leadership-jobs?k=Creative Team Leadership
# index: 316
# https://www.naukri.com/posting.-jobs?k=posting.
# index: 317
# https://www.naukri.com/Operating-jobs?k=Operating
# index: 318
# https://www.naukri.com/WinSCP-jobs?k=WinSCP
# index: 319
# https://www.naukri.com/Pleasing personality-jobs?k=Pleasing personality
# index: 320
# https://www.naukri.com/AJAX-jobs?k=AJAX
# index: 321
# https://www.naukri.com/l3vpn-jobs?k=l3vpn
# index: 322
# https://www.naukri.com/Clustering-jobs?k=Clustering
# index: 323
# https://www.naukri.com/Content Migration tools Metalogix and Sharegate-jobs?k=Content Migration tools Metalogix and Sharegate
# index: 324
# https://www.naukri.com/Project Management-jobs?k=Project Management
# index: 325
# https://www.naukri.com/Iterative Development-jobs?k=Iterative Development
# index: 326
# https://www.naukri.com/SVN.-jobs?k=SVN.
# index: 327
# https://www.naukri.com/Data Structures & Algorithms-jobs?k=Data Structures & Algorithms
# index: 328
# https://www.naukri.com/Oracle-jobs?k=Oracle
# index: 329
# https://www.naukri.com/Jackson-2-jobs?k=Jackson-2
# index: 330
# https://www.naukri.com/4.5-jobs?k=4.5
# index: 331
# https://www.naukri.com/SDET-jobs?k=SDET
# index: 332
# https://www.naukri.com/Frameworks (C#) 4.0-jobs?k=Frameworks (C#) 4.0
# index: 333
# https://www.naukri.com/Cucumber-jobs?k=Cucumber
# index: 334
# https://www.naukri.com/Inside Sales-jobs?k=Inside Sales
# index: 335
# https://www.naukri.com/Jdbc-jobs?k=Jdbc
# index: 336
# https://www.naukri.com/Oracle PeopleSoft-jobs?k=Oracle PeopleSoft
# index: 337
# https://www.naukri.com/JavaScript.-jobs?k=JavaScript.
# index: 338
# https://www.naukri.com/EMPLOYEE RESOURCE GROUP-jobs?k=EMPLOYEE RESOURCE GROUP
# index: 339
# https://www.naukri.com/jQuery-jobs?k=jQuery
# index: 340
# https://www.naukri.com/Selenium Web Driver)-jobs?k=Selenium Web Driver)
# index: 341
# https://www.naukri.com/DNS-jobs?k=DNS
# index: 342
# https://www.naukri.com/.net-jobs?k=.net
# index: 343
# https://www.naukri.com/ASP.Net with C#-jobs?k=ASP.Net with C#
# index: 344
# https://www.naukri.com/sql-jobs?k=sql
# index: 345
# https://www.naukri.com/CA7-jobs?k=CA7
# index: 346
# https://www.naukri.com/ C#-jobs?k= C#
# index: 347
# https://www.naukri.com/Good English-jobs?k=Good English
# index: 348
# https://www.naukri.com/VBA-jobs?k=VBA
# index: 349
# https://www.naukri.com/running-jobs?k=running
# index: 350
# https://www.naukri.com/DHCP-jobs?k=DHCP
# index: 351
# https://www.naukri.com/Domain Knowledge: E-commerce-jobs?k=Domain Knowledge: E-commerce
# index: 352
# https://www.naukri.com/knowledge of Active Directory-jobs?k=knowledge of Active Directory
# index: 353
# https://www.naukri.com/SOAP Web Services-jobs?k=SOAP Web Services
# index: 354
# https://www.naukri.com/SOAP UI-jobs?k=SOAP UI
# index: 355
# https://www.naukri.com/Java (Preliminary)-jobs?k=Java (Preliminary)
# index: 356
# https://www.naukri.com/Tomcat-jobs?k=Tomcat
# index: 357
# https://www.naukri.com/ESXi-jobs?k=ESXi
# index: 358
# https://www.naukri.com/Programming-jobs?k=Programming
# index: 359
# https://www.naukri.com/GitLab-jobs?k=GitLab
# index: 360
# https://www.naukri.com/Windows 7-jobs?k=Windows 7
# index: 361
# https://www.naukri.com/Salesforce-jobs?k=Salesforce
# index: 362
# https://www.naukri.com/Positive Attitude.-jobs?k=Positive Attitude.
# index: 363
# https://www.naukri.com/Technology: Multimedia-jobs?k=Technology: Multimedia
# index: 364
# https://www.naukri.com/Automation Testing-jobs?k=Automation Testing
# index: 365
# https://www.naukri.com/Strong Analytical and logical skills-jobs?k=Strong Analytical and logical skills
# index: 366
# https://www.naukri.com/Windows 8-jobs?k=Windows 8
# index: 367
# https://www.naukri.com/Software Development Life Cycle-jobs?k=Software Development Life Cycle
# index: 368
# https://www.naukri.com/Database SQL Server and Oracle-jobs?k=Database SQL Server and Oracle
# index: 369
# https://www.naukri.com/Unix-jobs?k=Unix
# index: 370
# https://www.naukri.com/JSP.-jobs?k=JSP.
# index: 371
# https://www.naukri.com/Javascript-jobs?k=Javascript
# index: 372
# https://www.naukri.com/REST-jobs?k=REST
# index: 373
# https://www.naukri.com/Junit-jobs?k=Junit
# index: 374
# https://www.naukri.com/Hard working with abstract thinking.-jobs?k=Hard working with abstract thinking.
# index: 375
# https://www.naukri.com/Databases and Tools Informatica Power Center-jobs?k=Databases and Tools Informatica Power Center
# index: 376
# https://www.naukri.com/C-jobs?k=C
# index: 377
# https://www.naukri.com/DDL-jobs?k=DDL
# index: 378
# https://www.naukri.com/Spring MVC-jobs?k=Spring MVC
# index: 379
# https://www.naukri.com/Sentimental Analysis-jobs?k=Sentimental Analysis
# index: 380
# https://www.naukri.com/and LAN/WAN.-jobs?k=and LAN/WAN.
# index: 381
# https://www.naukri.com/FlexBuilder-jobs?k=FlexBuilder
# index: 382
# https://www.naukri.com/Middleware MVC and WCF-jobs?k=Middleware MVC and WCF
# index: 383
# https://www.naukri.com/Java-jobs?k=Java
# index: 384
# https://www.naukri.com/Net beans-jobs?k=Net beans
# index: 385
# https://www.naukri.com/Tortoise SVN.-jobs?k=Tortoise SVN.
# index: 386
# https://www.naukri.com/SDLC Model: -Waterfall-jobs?k=SDLC Model: -Waterfall
# index: 387
# https://www.naukri.com/Oracle SQL Developer-jobs?k=Oracle SQL Developer
# index: 388
# https://www.naukri.com/kabbadi-jobs?k=kabbadi
# index: 389
# https://www.naukri.com/Core Java-jobs?k=Core Java
# index: 390
# https://www.naukri.com/PowerShell-jobs?k=PowerShell
# index: 391
# https://www.naukri.com/Mysql-jobs?k=Mysql
# index: 392
# https://www.naukri.com/MongoDB-jobs?k=MongoDB
# index: 393
# https://www.naukri.com/SOAP-jobs?k=SOAP
# index: 394
# https://www.naukri.com/QMF-jobs?k=QMF
# index: 395
# https://www.naukri.com/MS Visio-jobs?k=MS Visio
# index: 396
# https://www.naukri.com/CSS-jobs?k=CSS
# index: 397
# https://www.naukri.com/Excellent conceptual and analytical skills-jobs?k=Excellent conceptual and analytical skills
# index: 398
# https://www.naukri.com/Good communication skills-jobs?k=Good communication skills
# index: 399
# https://www.naukri.com/ABAP/4-jobs?k=ABAP/4
# index: 400
# https://www.naukri.com/JUnit-jobs?k=JUnit
# index: 401
# https://www.naukri.com/Flexible and high adaptability to new approaches-jobs?k=Flexible and high adaptability to new approaches
# index: 402
# https://www.naukri.com/Smart Working.-jobs?k=Smart Working.
# index: 403
# https://www.naukri.com/O365-jobs?k=O365
# index: 404
# https://www.naukri.com/ENTERPRISE-jobs?k=ENTERPRISE
# index: 405
# https://www.naukri.com/Users / Share folders creation and permission assigning.-jobs?k=Users / Share folders creation and permission assigning.
# index: 406
# https://www.naukri.com/MS Excel-jobs?k=MS Excel
# index: 407
# https://www.naukri.com/ClouStack-jobs?k=ClouStack
# index: 408
# https://www.naukri.com/Jira-jobs?k=Jira
# index: 409
# https://www.naukri.com/ORM Eclipse Link-jobs?k=ORM Eclipse Link
# index: 410
# https://www.naukri.com/swimming-jobs?k=swimming
# index: 411
# https://www.naukri.com/Xpeditor-jobs?k=Xpeditor
# index: 412
# https://www.naukri.com/CSS3-jobs?k=CSS3
# index: 413
# https://www.naukri.com/Microsoft Office-jobs?k=Microsoft Office
# index: 414
# https://www.naukri.com/MainView-jobs?k=MainView
# index: 415
# https://www.naukri.com/software integration-jobs?k=software integration
# index: 416
# https://www.naukri.com/Apache Nifi-jobs?k=Apache Nifi
# index: 417
# https://www.naukri.com/dns-jobs?k=dns
# index: 418
# https://www.naukri.com/SAP ABAP-jobs?k=SAP ABAP
# index: 419
# https://www.naukri.com/R-jobs?k=R
# index: 420
# https://www.naukri.com/SQL Server-jobs?k=SQL Server
# index: 421
# https://www.naukri.com/QTP-jobs?k=QTP
# index: 422
# https://www.naukri.com/Network-jobs?k=Network
# index: 423
# https://www.naukri.com/Web HTML-jobs?k=Web HTML

# %%
columns = ['title','url','experience','salary','location','skills','search_type']
df = pd.DataFrame(final_data)
#df.to_csv("MyDataset1.csv")
df2 = pd.DataFrame(final_data2)
#df2.to_csv("MyDataSet2.csv")
search=df2['search_type']
search
# Out:
# 0       Cryptography
# 1       Cryptography
# 2       Cryptography
# 3       Cryptography
# 4       Cryptography
#             ...
# 6397        Web HTML
# 6398        Web HTML
# 6399        Web HTML
# 6400        Web HTML
# 6401        Web HTML
# Name: search_type, Length: 6402, dtype: object

# %%
unique_search = search.unique()
unique_search
df_search = pd.DataFrame(unique_search)
df_search.to_csv("Unique_seach.csv")
